# %%
from data import Data

# %%
data = Data('../data/format-2011-world-copper-2063-trade.json')
logs = data.data

# %%
data.getMergedData()
# Out:
# {(8, 156): {'Trade Value': 25572338, 'Trade Quantity': 19206600},
#  (8, 792): {'Trade Value': 14086858, 'Trade Quantity': 10284547},
#  (12, 156): {'Trade Value': 427437, 'Trade Quantity': 256318},
#  (826, 24): {'Trade Value': 51, 'Trade Quantity': 1.0},
#  (32, 100): {'Trade Value': 74340292, 'Trade Quantity': 23540982},
#  (32, 152): {'Trade Value': 32591242, 'Trade Quantity': 10126472},
#  (32, 276): {'Trade Value': 621735272, 'Trade Quantity': 200007380},
#  (32, 392): {'Trade Value': 197600557, 'Trade Quantity': 62603653.0},
#  (32, 410): {'Trade Value': 371497150, 'Trade Quantity': 114399088},
#  (32, 608): {'Trade Value': 121929398, 'Trade Quantity': 37374344.0},
#  (32, 724): {'Trade Value': 137263923, 'Trade Quantity': 45007064},
#  (68, 32): {'Trade Value': 552028, 'Trade Quantity': 2701783},
#  (51, 100): {'Trade Value': 151742541, 'Trade Quantity': 59740070.0},
#  (51, 124): {'Trade Value': 4, 'Trade Quantity': 37.0},
# ...

# %%
logs
# Out:
#      Reporter Code   Reporter  Partner Code                           Partner  \
# 1                8    Albania           156                             China
# 2                8    Albania           792                            Turkey
# 3               12    Algeria           156                             China
# 4               24     Angola           826                    United Kingdom
# 5               32  Argentina            68  Bolivia (Plurinational State of)
# ..             ...        ...           ...                               ...
# 843            894     Zambia           757                       Switzerland
# 844            894     Zambia           784              United Arab Emirates
# 845            894     Zambia           826                    United Kingdom
# 846            894     Zambia           842                               USA
# 847            894     Zambia           842                               USA
#
# ...
